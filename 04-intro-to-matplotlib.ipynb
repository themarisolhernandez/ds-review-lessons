# %% [markdown]
# # 04 - Introduction to Matplotlib
# **Matplotlib** is a comprehensive library used for creating static, animated, and interactive visualizations in Python. It is a widely-used tool in data science to plot data in a visual format that allows us to better understand patterns, trends, and outliers. It can generate plots like line graphs, bar charts, scatter plots, histograms, and more.

# %% [markdown]
# ## Key Features of Matplotlib
# - **Ease of Use**: Easy syntax for creating basic visualizations.
#
# - **Customization**: Highly customizable, enabling control over plot elements like color, line styles, and legends.
#
# - **Integration**: Integrates seamlessly with libraries like NumPy and Pandas.

# %% [markdown]
# ## Installation
# To install Matplotlib, you can use `pip`:

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Once installed, you can import it as follows:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib is commonly imported with the alias `plt`. You only need to import a library **once** in your notebook to be able to use it in subsequent cells.

# %% [markdown]
# ## Basic Line Plot
# A **line plot** is the simplest way to visualize data. The line plot represents information at points connected by lines. It is useful to show the evolution of one or more data series along an axis, typically time. Here’s how you can create one:

# %%
# Data to plot
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# Create a line plot
plt.plot(x, y)

# Add a title, axis labels
plt.title('Basic Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# Show the plot
plt.show()

# %% [markdown]
# ## Scatter Plot
# **Scatter plots** are useful for showing the relationship between two variables

# %%
# Create data
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
y = [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]

# Create a scatter plot
plt.scatter(x, y)

# Add title and labels
plt.title('Basic Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# Show the plot
plt.show()

# %% [markdown]
# ## Bar Plot
# **Bar plots** are useful for comparing categories.

# %%
# Data to plot
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 1, 8]

# Create a bar plot
plt.bar(categories, values)

# Add a title and axis labels
plt.title('Basic Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show the plot
plt.show()

# %% [markdown]
# ## Histogram
# **Histograms** are used to represent the distribution of data.

# %%
import numpy as np

# Generate random data
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30)

# Add a title and labels
plt.title('Basic Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Customizing Plots
# Matplotlib allows you to customize plots in numerous ways. You can change line styles, colors, markers, and more. Let’s explore a few options:

# %%
# Data to plot
x = [0, 1, 2, 3]
y1 = [0, 1, 4, 9]
y2 = [0, 1, 2, 3]

# Plot two lines with different styles
plt.plot(x, y1, label='y = x^2', color='blue', marker='o', linestyle='--')
plt.plot(x, y2, label='y = x', color='green', marker='x', linestyle='-.')

# Add labels, title, and legend
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Customized Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Subplots
# Sometimes you may want to display multiple plots side-by-side. This can be done using subplots.

# %%
# Create subplots
fig, axs = plt.subplots(2, 2)

# Plot in different subplots
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Plot 1')

axs[0, 1].plot(x, y2)
axs[0, 1].set_title('Plot 2')

axs[1, 0].scatter(x, y1)
axs[1, 0].set_title('Plot 3')

axs[1, 1].bar(x, y2)
axs[1, 1].set_title('Plot 4')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Saving and Exporting Plots
# You can save your plot as an image using the `savefig()` function.

# %%
# Save the plot
plt.plot(x, y1)
plt.title('Saving Example')
plt.savefig('imgs/my_plot.png')

# Display the plot
plt.show()

# %% [markdown]
# ## Summary
# **Matplotlib** is an essential tool for any data scientist or Python developer working with data. Its flexibility allows for a wide range of visualizations that can be customized to meet your specific needs.

# %% [markdown]
# ## Additional Resources
# - [Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
#
# - [Matplotlib Cheat Sheet](https://github.com/matplotlib/cheatsheets)
#
# - [Matplotlib Tutorial (YouTube)](https://www.youtube.com/watch?v=ZyTO4SwhSeE)
#
# - [Kaggle's Visualization Course (Matplotlib)](https://www.kaggle.com/learn/data-visualization)
